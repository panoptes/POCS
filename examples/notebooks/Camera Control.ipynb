# %%
import time
from astropy.time import Time
import astropy.units as u

# %%
# Load the PANOPTES module dir
import sys
sys.path.append('../../')

# For development
# %load_ext autoreload
# %autoreload 2

from panoptes.utils.images import *
from panoptes import Panoptes
# Out:
# INFO:PanoptesLogger:
#
# INFO:PanoptesLogger:********************************************************************************
# INFO:PanoptesLogger:
#
# DEBUG:PanoptesLogger:Adding info logging to: PanError
# DEBUG:PanoptesLogger:Adding info logging to: SerialData
# DEBUG:PanoptesLogger:Adding info logging to: PanStateMachine
# DEBUG:PanoptesLogger:Adding info logging to: WeatherStation
# DEBUG:PanoptesLogger:Adding info logging to: Observation
# DEBUG:PanoptesLogger:Adding info logging to: Target
# DEBUG:PanoptesLogger:Adding info logging to: Scheduler
# DEBUG:PanoptesLogger:Adding info logging to: SchedulerSimple
# DEBUG:PanoptesLogger:Adding info logging to: PanIndiServer
# DEBUG:PanoptesLogger:Adding info logging to: PanIndiDevice
# DEBUG:PanoptesLogger:Adding info logging to: Observatory
# DEBUG:PanoptesLogger:Adding info logging to: Panoptes
# DEBUG:PanoptesLogger:Adding info logging to: Messaging
# DEBUG:PanoptesLogger:Adding info logging to: EnvironmentalMonitor
# DEBUG:PanoptesLogger:Adding info logging to: Webcams
# DEBUG:PanoptesLogger:Adding info logging to: PanSensors

# %%
pan = Panoptes()
# Out:
# DEBUG:PanoptesLogger:Adding info logging to: PanIndiDevice
# INFO:Panoptes:Initializing PANOPTES unit
# INFO:Panoptes:Using default state machine file: simple_state_table
# INFO:Panoptes:Setting up interrupt handlers for state machine
# DEBUG:Panoptes:Loading transition: {'dest': 'initializing', 'trigger': 'initialize', 'source': 'parked'}
# DEBUG:Panoptes:Returning transition: {'dest': 'initializing', 'trigger': 'initialize', 'conditions': ['weather_is_safe'], 'source': 'parked'}
# DEBUG:Panoptes:Loading transition: {'dest': 'initializing', 'trigger': 'initialize', 'source': 'sleeping'}
# DEBUG:Panoptes:Returning transition: {'dest': 'initializing', 'trigger': 'initialize', 'conditions': ['weather_is_safe'], 'source': 'sleeping'}
# DEBUG:Panoptes:Loading transition: {'dest': 'shutdown', 'trigger': 'shutdown', 'source': 'parked'}
# DEBUG:Panoptes:Returning transition: {'dest': 'shutdown', 'trigger': 'shutdown', 'conditions': ['weather_is_safe'], 'source': 'parked'}
# DEBUG:Panoptes:Loading transition: {'dest': 'sleeping', 'trigger': 'sleep', 'source': 'shutdown'}
# DEBUG:Panoptes:Returning transition: {'dest': 'sleeping', 'trigger': 'sleep', 'conditions': ['weather_is_safe'], 'source': 'shutdown'}
# DEBUG:Panoptes:Loading transition: {'dest': 'scheduling', 'trigger': 'schedule', 'source': 'initializing'}
# DEBUG:Panoptes:Returning transition: {'dest': 'scheduling', 'trigger': 'schedule', 'conditions': ['weather_is_safe'], 'source': 'initializing'}
# DEBUG:Panoptes:Loading transition: {'dest': 'slewing', 'trigger': 'acquire_target', 'conditions': 'is_dark', 'source': 'scheduling'}
# DEBUG:Panoptes:Returning transition: {'dest': 'slewing', 'trigger': 'acquire_target', 'conditions': ['is_dark', 'weather_is_safe'], 'source': 'scheduling'}
# DEBUG:Panoptes:Loading transition: {'dest': 'imaging', 'trigger': 'image', 'source': 'slewing'}
# DEBUG:Panoptes:Returning transition: {'dest': 'imaging', 'trigger': 'image', 'conditions': ['weather_is_safe'], 'source': 'slewing'}
# DEBUG:Panoptes:Loading transition: {'dest': 'analyzing', 'trigger': 'analyze', 'source': 'imaging'}
# DEBUG:Panoptes:Returning transition: {'dest': 'analyzing', 'trigger': 'analyze', 'conditions': ['weather_is_safe'], 'source': 'imaging'}
# DEBUG:Panoptes:Loading transition: {'dest': 'slewing', 'trigger': 'acquire_target', 'source': 'analyzing'}
# DEBUG:Panoptes:Returning transition: {'dest': 'slewing', 'trigger': 'acquire_target', 'conditions': ['weather_is_safe'], 'source': 'analyzing'}
# DEBUG:Panoptes:Loading parked state
# DEBUG:Panoptes:Loading parking state
# DEBUG:Panoptes:Loading shutdown state
# INFO:PanState:In shtudwon
# DEBUG:Panoptes:Loading sleeping state
# DEBUG:Panoptes:Loading initializing state
# DEBUG:Panoptes:Loading scheduling state
# DEBUG:Panoptes:Loading slewing state
# DEBUG:Panoptes:Loading imaging state
# DEBUG:Panoptes:Loading analyzing state
# INFO:Panoptes:State machine created
# INFO:Panoptes:Checking config
# INFO:Panoptes:Welcome PAN 001
# INFO:Panoptes:Setting up PAN 001:
# INFO:Panoptes:	 database connection
# INFO:Panoptes:	 weather station
# DEBUG:Panoptes:Creating weather station <class 'panoptes.weather.weather_station.WeatherStationMongo'>
# DEBUG:WeatherStation:Getting weather station connection to mongodb
# DEBUG:WeatherStation:Weather station connection: Collection(Database(MongoClient('localhost', 27017), 'panoptes'), 'sensors')
# INFO:Panoptes:	 observatory
# INFO:Observatory:Initializing observatory
# INFO:Observatory:	 Setting up location
# INFO:Observatory:Setting up site details of observatory
# DEBUG:Observatory:location set: {'pressure': <Quantity 0.68 bar>, 'timezone': 'US/Hawaii', 'horizon': <Quantity 18.0 deg>, 'latitude': <Quantity 19.54 deg>, 'elevation': <Quantity 3400.0 m>, 'name': 'Mauna Loa Observatory', 'longitude': <Quantity -155.58 deg>}
# DEBUG:Observatory:setting earth_location: {'pressure': <Quantity 0.68 bar>, 'timezone': 'US/Hawaii', 'horizon': <Quantity 18.0 deg>, 'latitude': <Quantity 19.54 deg>, 'elevation': <Quantity 3400.0 m>, 'name': 'Mauna Loa Observatory', 'longitude': <Quantity -155.58 deg>}
# DEBUG:PanIndiServer:Starting INDI Server: ['/usr/bin/indiserver', '-v', '-m', '100', '-f', '/tmp/pan_indiFIFO']
# DEBUG:PanIndiServer:INDI server started. PID: 5356
# DEBUG:PanIndiServer:Loading driver
# DEBUG:PanIndiServer:Command to FIFO server: start indi_simulator_ccd -n "PAN_CCD_SIMULATOR"
#
# INFO:Observatory:	 Setting up mount
# DEBUG:Observatory:Creating mount: ioptron
# INFO:Mount:Creating iOptron mount
# INFO:Mount:Setting up commands for mount
# INFO:Mount:Mount commands set up
# DEBUG:SerialData:Using threads
# DEBUG:SerialData:Serial connection set up to mount, sleeping for two seconds
# INFO:SerialData:SerialData created
# INFO:Mount:Mount created
# DEBUG:Observatory:Mount created
# INFO:Observatory:	 Setting up cameras
# DEBUG:Observatory:Camera config:
#  [{'model': 'canon_indi', 'connect_on_startup': False, 'port': 'usb:001,014', 'driver': 'indi_gphoto_ccd'}]
# DEBUG:Observatory:Creating camera: canon_indi
# DEBUG:Observatory:Loading indi_gphoto_ccd driver for Cam0.
# DEBUG:PanIndiServer:Loading driver
# DEBUG:PanIndiServer:Command to FIFO server: start indi_gphoto_ccd -n "Cam0"
#
# INFO:Camera:Creating device Cam0 (indi_gphoto_ccd)
# INFO:Camera:Camera Cam0 created on usb:001,014
# DEBUG:Camera:Connecting Cam0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.CONNECTION.CONNECT=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 connected
# DEBUG:Camera:Setting initial properties for Cam0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.aeb.aeb0=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.imageformatsd.imageformatsd9=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.CCD_ISO.ISO0=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.UPLOAD_SETTINGS.UPLOAD_DIR=/var/panoptes/images/']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.UPLOAD_SETTINGS.UPLOAD_PREFIX=IMAGE_XXX']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.ownername.ownername=Project PANOPTES']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.UPLOAD_MODE.UPLOAD_LOCAL=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.copyright.copyright=Project PANOPTES All Rights Reservered']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.Transfer Format.FITS=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.Transfer Format.Native=Off']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.artist.artist=Project PANOPTES']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.WCS_CONTROL.WCS_ENABLE=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.Auto Focus.Set=Off']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.picturestyle.picturestyle1=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.viewfinder.viewfinder1=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.reviewtime.reviewtime0=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.imageformatcf.imageformatcf9=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.autopoweroff.autopoweroff=0']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.CCD_COMPRESSION.CCD_RAW=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.CAPTURE_FORMAT.FORMAT9=On']
# DEBUG:Camera:Output from set_property: 0
# DEBUG:Camera:Getting properties for Cam0
# INFO:Camera:Cam0 connected
# DEBUG:Camera:['/usr/bin/indi_getprop', '-1', 'Cam0.CONNECTION.CONNECT']
# INFO:Camera:Output: ['Off'] <class 'list'>
# DEBUG:Observatory:Cameras created.
# INFO:Observatory:	 Setting up scheduler
# DEBUG:Observatory:Creating scheduler: /var/panoptes/POCS/resources/conf_files/targets/default_targets.yaml
# DEBUG:Observatory:Scheduler created
# INFO:Observatory:Observatory
# INFO:Panoptes:	 web interface
# DEBUG:Panoptes:Creating web interface: 8888
# WARNING:Panoptes:Port 8888 already in use. Going up one
# DEBUG:Panoptes:Listening to web loop on port 8889
# DEBUG:Panoptes:IOLoop already running.

# %%
cam = pan.observatory.cameras[0]

# %%
print(cam.get_all_properties())
# Out:
# DEBUG:Camera:['/usr/bin/indi_getprop', '-1', 'Cam0.*.*']
# INFO:Camera:Output: ['Cam0.CONNECTION.CONNECT=On', 'Cam0.CONNECTION.DISCONNECT=Off', 'Cam0.CONNECTION.CONNECT=Off', 'Cam0.CONNECTION.DISCONNECT=On', 'Cam0.DRIVER_INFO.DRIVER_NAME=GPhoto CCD', 'Cam0.DRIVER_INFO.DRIVER_EXEC=indi_gphoto_ccd', 'Cam0.DRIVER_INFO.DRIVER_VERSION=1.4', 'Cam0.DRIVER_INFO.DRIVER_INTERFACE=14', 'Cam0.CONFIG_PROCESS.CONFIG_LOAD=Off', 'Cam0.CONFIG_PROCESS.CONFIG_SAVE=Off', 'Cam0.CONFIG_PROCESS.CONFIG_DEFAULT=Off', 'Cam0.SHUTTER_PORT.PORT=', 'Cam0.DEBUG.ENABLE=Off', 'Cam0.DEBUG.DISABLE=On', 'Cam0.SIMULATION.ENABLE=Off', 'Cam0.SIMULATION.DISABLE=On', 'Cam0.DRIVER_INFO.DRIVER_NAME=GPhoto CCD', 'Cam0.DRIVER_INFO.DRIVER_EXEC=indi_gphoto_ccd', 'Cam0.DRIVER_INFO.DRIVER_VERSION=1.4', 'Cam0.DRIVER_INFO.DRIVER_INTERFACE=14', 'Cam0.CONFIG_PROCESS.CONFIG_LOAD=Off', 'Cam0.CONFIG_PROCESS.CONFIG_SAVE=Off', 'Cam0.CONFIG_PROCESS.CONFIG_DEFAULT=Off', 'Cam0.SHUTTER_PORT.PORT=', 'Cam0.DEBUG.ENABLE=Off', 'Cam0.DEBUG.DISABLE=On', 'Cam0.SIMULATION.ENABLE=Off', 'Cam0.SIMULATION.DISABLE=On', 'Cam0.CCD_EXPOSURE.CCD_EXPOSURE_VALUE=0', 'Cam0.CCD_FRAME.X=0', 'Cam0.CCD_FRAME.Y=0', 'Cam0.CCD_FRAME.WIDTH=1280', 'Cam0.CCD_FRAME.HEIGHT=1024', 'Cam0.SHUTTER_PORT.PORT=', 'Cam0.CCD_INFO.CCD_MAX_X=1280', 'Cam0.CCD_INFO.CCD_MAX_Y=1024', 'Cam0.CCD_INFO.CCD_PIXEL_SIZE=5.4000000953674316406', 'Cam0.CCD_INFO.CCD_PIXEL_SIZE_X=5.4000000953674316406', 'Cam0.CCD_INFO.CCD_PIXEL_SIZE_Y=5.4000000953674316406', 'Cam0.CCD_INFO.CCD_BITSPERPIXEL=8', 'Cam0.CCD_COMPRESSION.CCD_COMPRESS=Off', 'Cam0.CCD_COMPRESSION.CCD_RAW=On', 'Cam0.CCD_FRAME_TYPE.FRAME_LIGHT=On', 'Cam0.CCD_FRAME_TYPE.FRAME_BIAS=Off', 'Cam0.CCD_FRAME_TYPE.FRAME_DARK=Off', 'Cam0.CCD_FRAME_TYPE.FRAME_FLAT=Off', 'Cam0.CCD_CFA.CFA_OFFSET_X=0', 'Cam0.CCD_CFA.CFA_OFFSET_Y=0', 'Cam0.CCD_CFA.CFA_TYPE=RGGB', 'Cam0.CCD_RAPID_GUIDE.ENABLE=Off', 'Cam0.CCD_RAPID_GUIDE.DISABLE=On', 'Cam0.ACTIVE_DEVICES.ACTIVE_TELESCOPE=Telescope Simulator', 'Cam0.ACTIVE_DEVICES.ACTIVE_FOCUSER=Focuser Simulator', 'Cam0.ACTIVE_DEVICES.ACTIVE_FILTER=CCD Simulator', 'Cam0.WCS_CONTROL.WCS_ENABLE=On', 'Cam0.WCS_CONTROL.WCS_DISABLE=Off', 'Cam0.UPLOAD_MODE.UPLOAD_CLIENT=Off', 'Cam0.UPLOAD_MODE.UPLOAD_LOCAL=On', 'Cam0.UPLOAD_MODE.UPLOAD_BOTH=Off', 'Cam0.UPLOAD_SETTINGS.UPLOAD_DIR=/var/panoptes/images/', 'Cam0.UPLOAD_SETTINGS.UPLOAD_PREFIX=IMAGE_XXX', 'Cam0.CCD_ISO.ISO0=On', 'Cam0.CCD_ISO.ISO1=Off', 'Cam0.CCD_ISO.ISO2=Off', 'Cam0.CCD_ISO.ISO3=Off', 'Cam0.CCD_ISO.ISO4=Off', 'Cam0.CCD_ISO.ISO5=Off', 'Cam0.CCD_ISO.ISO6=Off', 'Cam0.CCD_ISO.ISO7=Off', 'Cam0.CCD_ISO.ISO8=Off', 'Cam0.CAPTURE_FORMAT.FORMAT0=Off', 'Cam0.CAPTURE_FORMAT.FORMAT1=Off', 'Cam0.CAPTURE_FORMAT.FORMAT2=Off', 'Cam0.CAPTURE_FORMAT.FORMAT3=Off', 'Cam0.CAPTURE_FORMAT.FORMAT4=Off', 'Cam0.CAPTURE_FORMAT.FORMAT5=Off', 'Cam0.CAPTURE_FORMAT.FORMAT6=Off', 'Cam0.CAPTURE_FORMAT.FORMAT7=Off', 'Cam0.CAPTURE_FORMAT.FORMAT8=Off', 'Cam0.CAPTURE_FORMAT.FORMAT9=On', 'Cam0.Transfer Format.FITS=On', 'Cam0.Transfer Format.Native=Off', 'Cam0.VIDEO_STREAM.Enable=Off', 'Cam0.VIDEO_STREAM.Disable=On', 'Cam0.Auto Focus.Set=Off', 'Cam0.FOCUS_MOTION.FOCUS_INWARD=On', 'Cam0.FOCUS_MOTION.FOCUS_OUTWARD=Off', 'Cam0.FOCUS_SPEED.FOCUS_SPEED_VALUE=0', 'Cam0.FOCUS_TIMER.FOCUS_TIMER_VALUE=1000', 'Cam0.TELESCOPE_TYPE.TELESCOPE_PRIMARY=On', 'Cam0.TELESCOPE_TYPE.TELESCOPE_GUIDE=Off', 'Cam0.CCD_ROTATION.CCD_ROTATION_VALUE=0', 'Cam0.SHUTTER_PORT.PORT=', 'Cam0.CCD_ISO.ISO0=On', 'Cam0.CCD_ISO.ISO1=Off', 'Cam0.CCD_ISO.ISO2=Off', 'Cam0.CCD_ISO.ISO3=Off', 'Cam0.CCD_ISO.ISO4=Off', 'Cam0.CCD_ISO.ISO5=Off', 'Cam0.CCD_ISO.ISO6=Off', 'Cam0.CCD_ISO.ISO7=Off', 'Cam0.CCD_ISO.ISO8=Off', 'Cam0.CAPTURE_FORMAT.FORMAT0=Off', 'Cam0.CAPTURE_FORMAT.FORMAT1=Off', 'Cam0.CAPTURE_FORMAT.FORMAT2=Off', 'Cam0.CAPTURE_FORMAT.FORMAT3=Off', 'Cam0.CAPTURE_FORMAT.FORMAT4=Off', 'Cam0.CAPTURE_FORMAT.FORMAT5=Off', 'Cam0.CAPTURE_FORMAT.FORMAT6=Off', 'Cam0.CAPTURE_FORMAT.FORMAT7=Off', 'Cam0.CAPTURE_FORMAT.FORMAT8=Off', 'Cam0.CAPTURE_FORMAT.FORMAT9=On', 'Cam0.Transfer Format.FITS=On', 'Cam0.Transfer Format.Native=Off', 'Cam0.VIDEO_STREAM.Enable=Off', ...
# {'CCD_CFA': {'CFA_TYPE': 'RGGB', 'CFA_OFFSET_Y': '0', 'CFA_OFFSET_X': '0'}, 'lensname': {'lensname': 'EF-S18-55mm f/3.5-5.6 IS STM'}, 'vendorextension': {'vendorextension': 'None'}, 'whitebalanceadjustb': {'whitebalanceadjustb1': 'Off', 'whitebalanceadjustb8': 'Off', 'whitebalanceadjustb18': 'Off', 'whitebalanceadjustb4': 'Off', 'whitebalanceadjustb5': 'Off', 'whitebalanceadjustb16': 'Off', 'whitebalanceadjustb9': 'On', 'whitebalanceadjustb12': 'Off', 'whitebalanceadjustb17': 'Off', 'whitebalanceadjustb3': 'Off', 'whitebalanceadjustb13': 'Off', 'whitebalanceadjustb10': 'Off', 'whitebalanceadjustb6': 'Off', 'whitebalanceadjustb2': 'Off', 'whitebalanceadjustb14': 'Off', 'whitebalanceadjustb11': 'Off', 'whitebalanceadjustb0': 'Off', 'whitebalanceadjustb15': 'Off', 'whitebalanceadjustb7': 'Off'}, 'Auto Focus': {'Set': 'Off'}, 'uilock': {'uilock0': 'On', 'uilock1': 'Off'}, 'd406': {'d406': 'Unknown Initiator'}, 'CCD_RAPID_GUIDE': {'DISABLE': 'On', 'ENABLE': 'Off'}, 'whitebalance': {'whitebalance1': 'Off', 'whitebalance6': 'Off', 'whitebalance2': 'Off', 'whitebalance4': 'Off', 'whitebalance7': 'Off', 'whitebalance0': 'On', 'whitebalance5': 'Off', 'whitebalance3': 'Off'}, 'SHUTTER_PORT': {'PORT': ''}, 'output': {'output7': 'Off', 'output0': 'On', 'output2': 'Off', 'output4': 'Off', 'output3': 'Off', 'output1': 'Off', 'output6': 'Off', 'output5': 'Off'}, 'cameramodel': {'cameramodel': 'Canon EOS REBEL SL1'}, 'customfuncex': {'customfuncex': '98,4,1,20,2,101,1,0,103,1,0,2,14,1,203,1,0,3,20,2,50e,1,0,60f,1,0,4,2c,3,701,1,0,704,1,0,811,1,0,'}, 'colortemperature': {'colortemperature': '5200'}, 'UPLOAD_MODE': {'UPLOAD_BOTH': 'Off', 'UPLOAD_CLIENT': 'Off', 'UPLOAD_LOCAL': 'On'}, 'DRIVER_INFO': {'DRIVER_EXEC': 'indi_gphoto_ccd', 'DRIVER_INTERFACE': '14', 'DRIVER_NAME': 'GPhoto CCD', 'DRIVER_VERSION': '1.4'}, '5001': {'50010': 'On', '50014': 'Off', '50012': 'Off', '50011': 'Off', '50013': 'Off'}, 'capturetarget': {'capturetarget0': 'On', 'capturetarget1': 'Off'}, 'depthoffield': {'depthoffield': '0'}, 'syncdatetime': {'syncdatetime0': 'Off', 'syncdatetime1': 'On'}, 'cancelautofocus': {'cancelautofocus1': 'On', 'cancelautofocus0': 'Off'}, 'TELESCOPE_TYPE': {'TELESCOPE_GUIDE': 'Off', 'TELESCOPE_PRIMARY': 'On'}, 'availableshots': {'availableshots': '11074'}, 'CCD_FRAME': {'WIDTH': '1280', 'X': '0', 'Y': '0', 'HEIGHT': '1024'}, 'focusinfo': {'focusinfo': 'eosversion=4,size=5184x3456,size2=5184x3456,points={{0,0,223,223},{0,730,119,181},{0,-730,119,181},{-821,388,172,128},{821,388,172,128},{-821,-388,172,128},{821,-388,172,128},{-1370,0,172,128},{1370,0,172,128}},select={},unknown={ff01000000000000ffff}'}, 'autoexposuremode': {'autoexposuremode7': 'Off', 'autoexposuremode12': 'Off', 'autoexposuremode9': 'Off', 'autoexposuremode5': 'Off', 'autoexposuremode0': 'Off', 'autoexposuremode3': 'On', 'autoexposuremode14': 'Off', 'autoexposuremode10': 'Off', 'autoexposuremode1': 'Off', 'autoexposuremode11': 'Off', 'autoexposuremode6': 'Off', 'autoexposuremode13': 'Off', 'autoexposuremode4': 'Off', 'autoexposuremode8': 'Off', 'autoexposuremode15': 'Off', 'autoexposuremode2': 'Off'}, 'bracketmode': {'bracketmode': '0'}, 'd407': {'d407': '1'}, 'CCD_EXPOSURE': {'CCD_EXPOSURE_VALUE': '0'}, 'datetime': {'datetime': 'Sun Nov  1 06:31:55 2015'}, 'deviceversion': {'deviceversion': '3-1.0.0'}, 'picturestyle': {'picturestyle3': 'Off', 'picturestyle0': 'Off', 'picturestyle8': 'Off', 'picturestyle5': 'Off', 'picturestyle6': 'Off', 'picturestyle7': 'Off', 'picturestyle9': 'Off', 'picturestyle2': 'Off', 'picturestyle1': 'On', 'picturestyle4': 'Off'}, 'FOCUS_MOTION': {'FOCUS_OUTWARD': 'Off', 'FOCUS_INWARD': 'On'}, 'CCD_ROTATION': {'CCD_ROTATION_VALUE': '0'}, 'focusmode': {'focusmode0': 'On', 'focusmode2': 'Off', 'focusmode1': 'Off'}, 'shuttercounter': {'shuttercounter': '258'}, 'CCD_FRAME_TYPE': {'FRAME_BIAS': 'Off', 'FRAME_LIGHT': 'On', 'FRAME_FLAT': 'Off', 'FRAME_DARK': 'Off'}, 'aeb': {'aeb0': 'On', 'aeb3': 'Off', 'aeb2': 'Off', 'aeb1': 'Off', 'aeb6': 'Off', 'aeb5': 'Off ...

# %%
cam.set_property('CCD_EXPOSURE', 'CCD_EXPOSURE_VALUE', 30.5)
# Out:
# DEBUG:Camera:Cam0 command: ['/usr/bin/indi_setprop', 'Cam0.CCD_EXPOSURE.CCD_EXPOSURE_VALUE=30.5']
# DEBUG:Camera:Output from set_property: 0
# 0
