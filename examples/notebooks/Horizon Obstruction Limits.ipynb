# %% [markdown]
# ## Horizon Constraints
#
# This notebook will demonstrate how the horizon line works.
#
# A `Horizon` accepts a list of `obstruction_points` as well as a `default_horizon` (with 30° as default). The `obstruction_points` is a list of at least two tuples where each tuple is an alt/az coordinate.  The idea is that you are defining a list of obstructions that will be interpolated between the given points. Thus, you have a "start" point and an "end" point (given in alt/az) for each obstruction. You can have as many obstructions as you want and obstructions can also contain "middle" points. See examples below for more details.
#
# The `Horizon` class automatically builds a `horizon_line` that is a list with 360 elements where each index of the list corresponds to an azimuth degree (0-360) and the value corresponds to the minimum allowed altitude for that azimuth.
#
# An example `obstruction_point` list might be (see below for plot of this example):
# ```
# [
#     [[40, 30], [40, 75]],   # From azimuth 30° to 75° there is an
#                             # obstruction that is at 40° altitude
#     [[50, 180], [40, 200]], # From azimuth 180° to 200° there is
#                             # an obstruction that slopes from 50°
#                             # to 40° altitude
# ]
# ```

# %%
# Basic imports for plotting
import matplotlib
matplotlib.use('Agg')

from matplotlib import pyplot as plt
# %matplotlib inline

import numpy as np

# %%
# Load config and horizon class
from pocs.utils.config import load_config
from pocs.utils.horizon import Horizon

# %%
# Get the default horizon
config = load_config()
default_horizon = config['location']['horizon']
default_horizon
# Out:
# <Quantity 30. deg>

# %%
# Helper function to plot - accepts `Horizon.horizon_line`
def plot_horizon(hline):
    az = np.arange(len(hline))

    fig, ax = plt.subplots(1)
    fig.set_figwidth(12)

    ax.plot(az, hline, '-')

    ax.set_xlim(0, 360)
    ax.set_xlabel('Azimuth / deg')
    ax.set_ylim(0, 90)
    ax.set_ylabel('Altitude / deg')
    
    ax.fill_between(az, 0, hline, alpha=0.2)

    plt.title('Horizon line')
    plt.show()

# %% [markdown]
# ### Horizon Examples

# %%
# Basic example
h1 = Horizon()
plot_horizon(h1.horizon_line)

# %%
# Lower default horizon
h2 = Horizon(default_horizon=5)
plot_horizon(h2.horizon_line)

# %%
# Intro example
points = [
    [[40, 30], [40, 75]],  
    [[50, 180], [40, 200]]
]
h3 = Horizon(points)
plot_horizon(h3.horizon_line)

# %%
# Example with three points
points = [
    [[25.0, 50.0], [25.0, 100.0]],               # Below default horizon
    [[40.0, 180.0], [50.0, 190.0], [45., 200.]], # Three points
    [[33.0, 10.0], [40.0, 20.0]],    
]
h4 = Horizon(points, default_horizon=33)
plot_horizon(h4.horizon_line)

# %%
# Radio tower
points = [
    [[75.0, 300.0], [75.0, 302.0]],
]
plot_horizon(Horizon(points).horizon_line)

# %%
# Funky buildings; overlapping azimuths, negative azimuths; out of order
points = [
    [[75.0, 300.0], [75.0, 305.0]], # Far right overlapping
    [[70.0, 295.0], [60.0, 310.0]],
    
    [[75.0, -165.0], [75.0, -160.0]], # Middle funky
    [[70.0, -165.0], [60.0, -150.0]],    
    
    [[75.0, 15.0], [75.0, 25.0]],   # Left side 1
    [[65.0, 55.0], [65.0, 65.0]],   # Left side 2 
    [[55.0, 105.0], [55.0, 115.0]], # Left side 3   
]
plot_horizon(Horizon(points).horizon_line)

# %%
# Pyramids! Note order of obstruction points doesn't matter
points = [
    [[10.0, 50.0], [45., 80.], [10.0, 110.0]], # Big
    [[10.0, 300.0], [25., 320.], [10.0, 340.0]], # Medium
    [[10.0, 200.0], [15., 205.], [10.0, 210.0]], # Tiny
]
plot_horizon(Horizon(points, default_horizon=10).horizon_line)

# %%
# Random horizon
import random
range_length = 360
points = [list(list(a) for a in zip(
        [random.randrange(15, 50) for _ in range(range_length)], # Random height
        np.arange(1, range_length, 25) # Set azimuth
    ))]
plot_horizon(Horizon(points).horizon_line)

# %% [markdown]
# ### Scheduler example
#
# The horizon is used in the `Altitude` constraint. Note that at this point it is just checking the altitude at the start of the observation (I think). This definitely needs some work and some testing but the mechanisms are in place.

# %%
from pocs.core import POCS
from pocs.observatory import Observatory

obs = Observatory(simulator=['all'])
pocs = POCS(obs)

# %%
pocs.observatory.get_observation()

# %%
# !grc tail -n139 /var/panoptes/logs/__main__.py.log
# Out:
# D0116 12:30:20.712 observatory.py:182   Getting observation for observatory
# I0116 12:30:21.285 dispatch.py:56       Checking Constraint: Altitude
# D0116 12:30:21.285 dispatch.py:59       	Observation: Kepler 1100
# D0116 12:30:21.334 constraint.py:152    		Below minimum altitude: -18.37 deg < 30.00 deg
# D0116 12:30:21.334 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.334 dispatch.py:67       		Kepler 1100 vetoed by Altitude
# D0116 12:30:21.334 dispatch.py:59       	Observation: KIC 8462852
# D0116 12:30:21.383 constraint.py:152    		Below minimum altitude: -21.63 deg < 30.00 deg
# D0116 12:30:21.383 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.383 dispatch.py:67       		KIC 8462852 vetoed by Altitude
# D0116 12:30:21.383 dispatch.py:59       	Observation: HD 189733
# D0116 12:30:21.432 constraint.py:152    		Below minimum altitude: -39.88 deg < 30.00 deg
# D0116 12:30:21.432 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.432 dispatch.py:67       		HD 189733 vetoed by Altitude
# D0116 12:30:21.432 dispatch.py:59       	Observation: HD 209458
# D0116 12:30:21.481 constraint.py:152    		Below minimum altitude: -51.37 deg < 30.00 deg
# D0116 12:30:21.482 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.482 dispatch.py:67       		HD 209458 vetoed by Altitude
# D0116 12:30:21.482 dispatch.py:59       	Observation: Wasp 140
# D0116 12:30:21.530 constraint.py:152    		Below minimum altitude: -4.32 deg < 30.00 deg
# D0116 12:30:21.531 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.531 dispatch.py:67       		Wasp 140 vetoed by Altitude
# D0116 12:30:21.531 dispatch.py:59       	Observation: Wasp 104
# D0116 12:30:21.579 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:21.579 dispatch.py:59       	Observation: Wasp 44
# D0116 12:30:21.626 constraint.py:152    		Below minimum altitude: -54.36 deg < 30.00 deg
# D0116 12:30:21.626 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.626 dispatch.py:67       		Wasp 44 vetoed by Altitude
# D0116 12:30:21.627 dispatch.py:59       	Observation: Wasp 2
# D0116 12:30:21.674 constraint.py:152    		Below minimum altitude: -57.38 deg < 30.00 deg
# D0116 12:30:21.675 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.675 dispatch.py:67       		Wasp 2 vetoed by Altitude
# D0116 12:30:21.675 dispatch.py:59       	Observation: Wasp 24
# D0116 12:30:21.726 constraint.py:152    		Below minimum altitude: 10.62 deg < 30.00 deg
# D0116 12:30:21.726 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.726 dispatch.py:67       		Wasp 24 vetoed by Altitude
# D0116 12:30:21.726 dispatch.py:59       	Observation: Wasp 77
# D0116 12:30:21.776 constraint.py:152    		Below minimum altitude: -21.63 deg < 30.00 deg
# D0116 12:30:21.776 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.776 dispatch.py:67       		Wasp 77 vetoed by Altitude
# D0116 12:30:21.776 dispatch.py:59       	Observation: Wasp 33
# D0116 12:30:21.825 constraint.py:152    		Below minimum altitude: -3.57 deg < 30.00 deg
# D0116 12:30:21.825 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.825 dispatch.py:67       		Wasp 33 vetoed by Altitude
# D0116 12:30:21.825 dispatch.py:59       	Observation: Wasp 43
# D0116 12:30:21.873 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:21.873 dispatch.py:59       	Observation: Wasp 36
# D0116 12:30:21.922 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:21.922 dispatch.py:59       	Observation: Wasp 11
# D0116 12:30:21.976 constraint.py:152    		Below minimum altitude: 1.53 deg < 30.00 deg
# D0116 12:30:21.976 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:21.976 dispatch.py:67       		Wasp 11 vetoed by Altitude
# D0116 12:30:21.976 dispatch.py:59       	Observation: Wasp 35
# D0116 12:30:22.025 constraint.py:152    		Below minimum altitude: 15.05 deg < 30.00 deg
# D0116 12:30:22.026 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.026 dispatch.py:67       		Wasp 35 vetoed by Altitude
# D0116 12:30:22.026 dispatch.py:59       	Observation: HAT-P-20
# D0116 12:30:22.089 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:22.089 dispatch.py:59       	Observation: Qatar-1
# D0116 12:30:22.149 constraint.py:152    		Below minimum altitude: -3.20 deg < 30.00 deg
# D0116 12:30:22.149 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.149 dispatch.py:67       		Qatar-1 vetoed by Altitude
# D0116 12:30:22.150 dispatch.py:59       	Observation: Qatar-2
# D0116 12:30:22.199 constraint.py:152    		Below minimum altitude: 25.33 deg < 30.00 deg
# D0116 12:30:22.199 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.199 dispatch.py:67       		Qatar-2 vetoed by Altitude
# D0116 12:30:22.199 dispatch.py:59       	Observation: Tres 3
# D0116 12:30:22.249 constraint.py:152    		Below minimum altitude: -9.96 deg < 30.00 deg
# D0116 12:30:22.249 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.249 dispatch.py:67       		Tres 3 vetoed by Altitude
# D0116 12:30:22.249 dispatch.py:59       	Observation: EPIC-211089792
# D0116 12:30:22.298 constraint.py:152    		Below minimum altitude: 12.35 deg < 30.00 deg
# D0116 12:30:22.298 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.298 dispatch.py:67       		EPIC-211089792 vetoed by Altitude
# D0116 12:30:22.298 dispatch.py:59       	Observation: HAT-P-1
# D0116 12:30:22.348 constraint.py:152    		Below minimum altitude: -29.61 deg < 30.00 deg
# D0116 12:30:22.348 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.348 dispatch.py:67       		HAT-P-1 vetoed by Altitude
# D0116 12:30:22.348 dispatch.py:59       	Observation: HAT-P-12
# D0116 12:30:22.397 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:22.397 dispatch.py:59       	Observation: HAT-P-36
# D0116 12:30:22.445 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:22.446 dispatch.py:59       	Observation: HAT-P-37
# D0116 12:30:22.493 constraint.py:152    		Below minimum altitude: -9.58 deg < 30.00 deg
# D0116 12:30:22.493 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.494 dispatch.py:67       		HAT-P-37 vetoed by Altitude
# D0116 12:30:22.494 dispatch.py:59       	Observation: M42
# D0116 12:30:22.542 constraint.py:152    		Below minimum altitude: 22.46 deg < 30.00 deg
# D0116 12:30:22.542 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.542 dispatch.py:67       		M42 vetoed by Altitude
# D0116 12:30:22.542 dispatch.py:59       	Observation: M44
# D0116 12:30:22.590 dispatch.py:64       		Score: 100.00000	Veto: False
# D0116 12:30:22.590 dispatch.py:59       	Observation: M45
# D0116 12:30:22.638 constraint.py:152    		Below minimum altitude: 7.19 deg < 30.00 deg
# D0116 12:30:22.638 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.638 dispatch.py:67       		M45 vetoed by Altitude
# D0116 12:30:22.638 dispatch.py:59       	Observation: M5
# D0116 12:30:22.687 constraint.py:152    		Below minimum altitude: 8.25 deg < 30.00 deg
# D0116 12:30:22.687 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.687 dispatch.py:67       		M5 vetoed by Altitude
# I0116 12:30:22.687 dispatch.py:56       Checking Constraint: Moon Avoidance
# D0116 12:30:22.687 dispatch.py:59       	Observation: Wasp 104
# D0116 12:30:22.701 dispatch.py:64       		Score: 0.24136	Veto: False
# D0116 12:30:22.701 dispatch.py:59       	Observation: Wasp 43
# D0116 12:30:22.717 dispatch.py:64       		Score: 0.26493	Veto: False
# D0116 12:30:22.717 dispatch.py:59       	Observation: Wasp 36
# D0116 12:30:22.732 dispatch.py:64       		Score: 0.17772	Veto: False
# D0116 12:30:22.732 dispatch.py:59       	Observation: HAT-P-20
# D0116 12:30:22.747 constraint.py:114    		Moon separation: 6.41
# D0116 12:30:22.747 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.747 dispatch.py:67       		HAT-P-20 vetoed by Moon Avoidance
# D0116 12:30:22.747 dispatch.py:59       	Observation: HAT-P-12
# D0116 12:30:22.762 dispatch.py:64       		Score: 0.42679	Veto: False
# D0116 12:30:22.762 dispatch.py:59       	Observation: HAT-P-36
# D0116 12:30:22.777 dispatch.py:64       		Score: 0.34274	Veto: False
# D0116 12:30:22.777 dispatch.py:59       	Observation: M44
# D0116 12:30:22.792 constraint.py:114    		Moon separation: 11.57
# D0116 12:30:22.792 dispatch.py:64       		Score: 0.00000	Veto: True
# D0116 12:30:22.792 dispatch.py:67       		M44 vetoed by Moon Avoidance
# I0116 12:30:22.792 dispatch.py:56       Checking Constraint: Duration above 30.0 deg
# D0116 12:30:22.792 dispatch.py:59       	Observation: Wasp 104
# D0116 12:30:23.203 constraint.py:67     		Observation minimum can't be met before meridian flip
# D0116 12:30:23.283 constraint.py:79     		Target sets past end_of_night, using end_of_night
# D0116 12:30:23.284 dispatch.py:64       		Score: 1.00000	Veto: True
# D0116 12:30:23.284 dispatch.py:67       		Wasp 104 vetoed by Duration above 30.0 deg
# D0116 12:30:23.284 dispatch.py:59       	Observation: Wasp 43
# D0116 12:30:23.679 constraint.py:67     		Observation minimum can't be met before meridian flip
# D0116 12:30:23.757 constraint.py:79     		Target sets past end_of_night, using end_of_night
# D0116 12:30:23.758 dispatch.py:64       		Score: 1.00000	Veto: True
# D0116 12:30:23.758 dispatch.py:67       		Wasp 43 vetoed by Duration above 30.0 deg
# D0116 12:30:23.758 dispatch.py:59       	Observation: Wasp 36
# D0116 12:30:24.244 dispatch.py:64       		Score: 0.78963	Veto: False
# D0116 12:30:24.244 dispatch.py:59       	Observation: HAT-P-12
# D0116 12:30:24.717 constraint.py:79     		Target sets past end_of_night, using end_of_night
# D0116 12:30:24.718 dispatch.py:64       		Score: 1.00000	Veto: False
# D0116 12:30:24.718 dispatch.py:59       	Observation: HAT-P-36
# D0116 12:30:25.199 constraint.py:79     		Target sets past end_of_night, using end_of_night
# D0116 12:30:25.199 dispatch.py:64       		Score: 1.00000	Veto: False
# I0116 12:30:25.200 scheduler.py:112     Setting new observation to HAT-P-12: 120.0 s exposures in blocks of 10, minimum 60, priority 100
