# %%
import sys
sys.path.append('../..')

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
from IPython.display import Image

# %%
from pocs.utils import dither
# Out:
# WARNING: OldEarthOrientationDataWarning: Your version of the IERS Bulletin A is 19.5 days old. For best precision (on the order of arcseconds), you must download an up-to-date IERS Bulletin A table. To do so, run:
#
# >>> from astroplan import download_IERS_A
# >>> download_IERS_A()
#  [astroplan.utils]

# %% [markdown]
# # Create a base position
#
# Chose an arbitrary sky position close to the South Celestial Pole to demonstrate correct handing of angular separations and projections.

# %%
base = SkyCoord('4h23m45.3s -87d23m56s')

# %%
base
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     ( 65.93875, -87.39888889)>

# %%
base.to_string('hmsdms')
# Out:
# '04h23m45.3s -87d23m56s'

# %% [markdown]
# # Dice 5 pattern dither, no random offsets

# %%
dice5_positions = dither.get_dither_positions(base_position=base, 
                                              n_positions=5, 
                                              pattern=dither.dice5,
                                              pattern_offset=30 * u.arcminute,
                                              plot='dice5.png')

# %%
dice5_positions
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [( 65.93875   , -87.39888889), ( 75.10209782, -86.85886247),
#      ( 79.32726611, -87.84026465), ( 52.55023389, -87.84026465),
#      ( 56.77540218, -86.85886247)]>

# %%
dice5_positions.to_string('hmsdms')
# Out:
# ['04h23m45.3s -87d23m56s',
#  '05h00m24.5035s -86d51m31.9049s',
#  '05h17m18.5439s -87d50m24.9527s',
#  '03h30m12.0561s -87d50m24.9527s',
#  '03h47m06.0965s -86d51m31.9049s']

# %%
Image('dice5.png')

# %% [markdown]
# # Random offsets only

# %%
random_positions = dither.get_dither_positions(base_position=base, 
                                               n_positions=20, 
                                               random_offset=0.5 * u.degree, 
                                               plot='random.png')

# %%
random_positions
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [( 58.52536149, -87.18389526), ( 71.28033249, -87.56684574),
#      ( 63.38357617, -87.17088849), ( 69.99091382, -87.43828787),
#      ( 57.50295192, -87.67553472), ( 68.54466362, -87.8023115 ),
#      ( 74.95457266, -87.49299184), ( 59.61894017, -87.07325659),
#      ( 69.19278667, -87.16382609), ( 58.75089593, -87.86697519),
#      ( 72.15896558, -87.34964232), ( 70.42461536, -87.81028167),
#      ( 58.04588675, -86.97560816), ( 68.57203228, -87.19867365),
#      ( 69.98591796, -86.96258896), ( 75.70736253, -87.80385823),
#      ( 66.45607249, -87.65547691), ( 64.26952074, -87.02128571),
#      ( 76.24275652, -87.380819  ), ( 60.94767636, -87.00280864)]>

# %%
random_positions.to_string('hmsdms')
# Out:
# ['03h54m06.0868s -87d11m02.0229s',
#  '04h45m07.2798s -87d34m00.6447s',
#  '04h13m32.0583s -87d10m15.1986s',
#  '04h39m57.8193s -87d26m17.8363s',
#  '03h50m00.7085s -87d40m31.925s',
#  '04h34m10.7193s -87d48m08.3214s',
#  '04h59m49.0974s -87d29m34.7706s',
#  '03h58m28.5456s -87d04m23.7237s',
#  '04h36m46.2688s -87d09m49.7739s',
#  '03h55m00.215s -87d52m01.1107s',
#  '04h48m38.1517s -87d20m58.7123s',
#  '04h41m41.9077s -87d48m37.014s',
#  '03h52m11.0128s -86d58m32.1894s',
#  '04h34m17.2877s -87d11m55.2252s',
#  '04h39m56.6203s -86d57m45.3202s',
#  '05h02m49.767s -87d48m13.8896s',
#  '04h25m49.4574s -87d39m19.7169s',
#  '04h17m04.685s -87d01m16.6286s',
#  '05h04m58.2616s -87d22m50.9484s',
#  '04h03m47.4423s -87d00m10.1111s']

# %%
Image('random.png')

# %% [markdown]
# # Dice 9 pattern dither with random offsets

# %%
dice9_positions = dither.get_dither_positions(base_position=base, 
                                              n_positions=20, 
                                              pattern=dither.dice9, 
                                              pattern_offset=30*u.arcminute, 
                                              random_offset=100*u.arcsecond, 
                                              plot='dice9.png')

# %%
dice9_positions
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.17148503, -87.38245856), ( 65.78610009, -86.92390628),
#      ( 74.98594655, -86.87751795), ( 76.96041175, -87.3772629 ),
#      ( 79.48094335, -87.84130836), ( 65.78711039, -87.91046268),
#      ( 53.0555063 , -87.81738436), ( 55.31739653, -87.34786014),
#      ( 56.97688076, -86.86638427), ( 66.22129316, -87.41887784),
#      ( 65.58530412, -86.87851108), ( 75.19759137, -86.84351869),
#      ( 76.96898049, -87.34787502), ( 79.99062016, -87.8601507 ),
#      ( 65.58408842, -87.92425782), ( 51.83043887, -87.84539368),
#      ( 55.10110297, -87.33017172), ( 56.78979055, -86.83405426),
#      ( 66.38584247, -87.40196747), ( 65.74197347, -86.87907009)]>

# %%
dice9_positions.to_string('hmsdms')
# Out:
# ['04h24m41.1564s -87d22m56.8508s',
#  '04h23m08.664s -86d55m26.0626s',
#  '04h59m56.6272s -86d52m39.0646s',
#  '05h07m50.4988s -87d22m38.1464s',
#  '05h17m55.4264s -87d50m28.7101s',
#  '04h23m08.9065s -87d54m37.6656s',
#  '03h32m13.3215s -87d49m02.5837s',
#  '03h41m16.1752s -87d20m52.2965s',
#  '03h47m54.4514s -86d51m58.9834s',
#  '04h24m53.1104s -87d25m07.9602s',
#  '04h22m20.473s -86d52m42.6399s',
#  '05h00m47.4219s -86d50m36.6673s',
#  '05h07m52.5553s -87d20m52.3501s',
#  '05h19m57.7488s -87d51m36.5425s',
#  '04h22m20.1812s -87d55m27.3281s',
#  '03h27m19.3053s -87d50m43.4172s',
#  '03h40m24.2647s -87d19m48.6182s',
#  '03h47m09.5497s -86d50m02.5953s',
#  '04h25m32.6022s -87d24m07.0829s',
#  '04h22m58.0736s -86d52m44.6523s']

# %%
Image('dice9.png')
